# %% [markdown]
# $Task-3$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv('Visadataset.csv')

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['continent'].value_counts().values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %% [markdown]
# **Using for loop plot the bar charts for the categorical columns**
# - we can use seaborn and matplotlib
# - Seaborn: countplot only data directly column name and main data
# - Matplotlib: requires frequency table
#     - from raw data, will make values counts
#     - from values count we are making keys and values seperatly
#     - then we are creating a dataframe
# - start will seaborn
#     - then we require cat column names and main dataframe
# - Start with matplotlib
#     - we already created a folder called Values_Counts_df

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mohit\\Data_Science\\In_Class\\EDA'

# %% [markdown]
# **os.makedirs()**
# - It will create a leaf directory
# - means it will the current working directory and creates a extra folder
# - The base folder where the workbook is located in EDA
# - Now if we want to create a new folder **Graphs_seaborn**
# - which is one step ahead of EDA folder: EDA/graphs_seaborn
# - pass the full path inside os.makedirs()
# - C:\Users\mohit\Data_Science\In_Class\EDA

# %%
os.makedirs(r'C:\Users\mohit\Data_Science\In_Class\EDA\graph_seaborn')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.makedirs(r'C:\Users\mohit\Data_Science\In_Class\EDA\graph_seaborn')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\mohit\\Data_Science\\In_Class\\EDA\\graph_seaborn'

# %% [markdown]
# **Step-1**
# - root_directory=os.getcwd()
# - root directory
# **Step-2**
# - new_folder="graphs_seaborn"
# **Step-3**
# - new_dir = os.path.join(root_directory,new_folder)
# - new_dir
# **Step-4**
# - new_dir+'\\'+'Folder_name'

# %%
types = dict(visa_df.dtypes)
cat_columns = [key for key, value in types.items() if value=='object']
nume_column = [key for key, value in types.items() if value!='object']

# %%
root_dir = os.getcwd()
new_folder = 'Graph_seaborn'
new_dir = os.path.join(root_dir,new_folder)
new_dir
# Out:
# 'C:\\Users\\mohit\\Data_Science\\In_Class\\EDA\\Graph_seaborn'

# %%
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_continents = visa_df[i].value_counts().keys()
    sns.countplot(data = visa_df,
                 x = i,
                 order = order_continents)
    plt.title('Bar chart')
    plt.savefig(f'{new_dir}\{i}_seaborn.jpg')
    plt.show()

# %%
file_loc=os.listdir(new_dir)
file_loc
# Out:
# ['case_status_seaborn.jpg',
#  'continent_seaborn.jpg',
#  'education_of_employee_seaborn.jpg',
#  'full_time_position_seaborn.jpg',
#  'has_job_experience_seaborn.jpg',
#  'region_of_employment_seaborn.jpg',
#  'requires_job_training_seaborn.jpg',
#  'unit_of_wage_seaborn.jpg']

# %% [markdown]
# $Task-4$

# %% [markdown]
# **Using Matplotlib**

# %%
for i in :
    df = pd.read_csv(i)
    plt.figure(figsize=(8,5))
    plt.bar('Labels',
           'Count',
           data=df)
    plt.title('Bar Chart')
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.savefig(f'{new_dir}\{i}_matplotlib.jpg')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 for i in cat_columns[1:]:
# ----> 2     df = pd.read_csv(i)
#       3     plt.figure(figsize=(8,5))
#       4     plt.bar('label',
#       5            'Count',
#       6            data=df)
#
# ...
