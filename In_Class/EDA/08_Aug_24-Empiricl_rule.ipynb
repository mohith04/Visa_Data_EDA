# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Histogram**
# - By applying the empirical rule we can observe slight deviation in the count of data
# - Also mena is a slight deviation from the median
# - this gives an indication the data does not follow Normal distribution
# - to understand more clearly will visualize the data
# - it is Numerical data, so the plot name is:**Histogram**
# - A histogram is a graph between Class intervals and class interval frequency
# - the plot is available in **matplotlib**
# - the method name is **hist**

# %%
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
wage_data = visa_df['prevailing_wage']
plt.hist(x=wage_data,bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# - Histogram will return 3 values
#     1. interval count
#         - if we have 20 intervals, so we have 20 interval counts
#     2. bins
#         - bis means the number of intervals
#         - we have 20 intervals so we need 21 values
#     3. It will display how many intervals are available
# - for eg in the bins array the first two from one interval
#     1. For the first interval
#         - 2.1367 to 15962.543 the count is 3863
#         - 3863 observations are available between 2.1367 to 15962.543
#     2. For the second interval
#         - 15962.543 to 31922.95 the count is 2175
#         - 2175 observations are available between 15962.543 to 31922.95
#     3. For the third interval
#         - 31922.95 to 47883.3567 the count is 2676
#         - 2676 observations are available between 31922.95 to 47883.3567

# %%
wage_data = visa_df['prevailing_wage']
count,bins,x = plt.hist(wage_data,20)
print(len(count))
print (len(bins))
print (x)
# Out:
# 20
# 21
# <BarContainer object of 20 artists>

# %%
low_b = 2.136
upper_b = 15962.543
con_1_sigma_2 = visa_df['prevailing_wage']<upper_b
con_2_sigma_2 = visa_df['prevailing_wage']>low_b
con_sigma_2 = con_1_sigma_2 & con_2_sigma_2
visa_df[con_sigma_2]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 36        EZYV37         Europe           High School                  Y
# 54        EZYV55           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25460  EZYV25461         Europe              Master's                  Y
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
low_b = 15962.543
upper_b = 31922.95
con_1_sigma_2 = visa_df['prevailing_wage']<upper_b
con_2_sigma_2 = visa_df['prevailing_wage']>low_b
con_sigma_2 = con_1_sigma_2 & con_2_sigma_2
visa_df[con_sigma_2]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 12        EZYV13      Asia            Bachelor's                  Y
# 17        EZYV18      Asia              Master's                  Y
# 44        EZYV45      Asia           High School                  Y
# 45        EZYV46    Europe            Bachelor's                  N
# 100      EZYV101      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25404  EZYV25405   Oceania             Doctorate                  Y
# 25410  EZYV25411      Asia              Master's                  Y
# 25445  EZYV25446      Asia            Bachelor's                  Y
# 25457  EZYV25458      Asia              Master's                  Y
# 25473  EZYV25474      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 12                        N           123876         1963
# ...

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
dir(wage_data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
dict_counts_bins = {}
null = []
for keys,values in zip(bins,count):
    dict_counts_bins[keys]=values 
    if values == null:
        dict_counts_bins[keys]=values 
dict_counts_bins
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_5656\430262437.py:5: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if values == null:
# {2.1367: 3863.0,
#  15962.543365000001: 2175.0,
#  31922.950030000004: 2676.0,
#  47883.35669500001: 2828.0,
#  63843.76336000001: 2889.0,
#  79804.17002500001: 2792.0,
#  95764.57669000002: 2485.0,
#  111724.98335500002: 2066.0,
#  127685.39002000002: 1452.0,
#  143645.79668500004: 882.0,
#  159606.20335000003: 408.0,
#  175566.610015: 216.0,
#  191527.01668000003: 206.0,
#  207487.42334500005: 167.0,
#  223447.83001000003: 129.0,
#  239408.23667500002: 111.0,
#  255368.64334000004: 66.0,
#  271329.050005: 48.0,
#  287289.45667000004: 10.0,
#  303249.863335: 11.0}

# %%
list1=[]
for i in range(len(bins)):
    if i!=20:
        x=bins[i]
        y=bins[i+1]
        z=(f'{round(x,2)} - {round(y,2)}')
        list1.append(z)
    else:
        break
rang_df=pd.DataFrame(zip(list1,count),columns=['Range','Count'])
rang_df
# Out:
#                     Range   Count
# 0         2.14 - 15962.54  3863.0
# 1     15962.54 - 31922.95  2175.0
# 2     31922.95 - 47883.36  2676.0
# 3     47883.36 - 63843.76  2828.0
# 4     63843.76 - 79804.17  2889.0
# 5     79804.17 - 95764.58  2792.0
# 6    95764.58 - 111724.98  2485.0
# 7   111724.98 - 127685.39  2066.0
# 8    127685.39 - 143645.8  1452.0
# 9     143645.8 - 159606.2   882.0
# 10   159606.2 - 175566.61   408.0
# 11  175566.61 - 191527.02   216.0
# 12  191527.02 - 207487.42   206.0
# 13  207487.42 - 223447.83   167.0
# 14  223447.83 - 239408.24   129.0
# 15  239408.24 - 255368.64   111.0
# 16  255368.64 - 271329.05    66.0
# 17  271329.05 - 287289.46    48.0
# 18  287289.46 - 303249.86    10.0
# 19  303249.86 - 319210.27    11.0

# %%
counts_bins_df = pd.DataFrame(zip(bins,count),columns=columns_bins_counts)
counts_bins_df
# Out:
#               Bin   Count
# 0        2.136700  3863.0
# 1    15962.543365  2175.0
# 2    31922.950030  2676.0
# 3    47883.356695  2828.0
# 4    63843.763360  2889.0
# 5    79804.170025  2792.0
# 6    95764.576690  2485.0
# 7   111724.983355  2066.0
# 8   127685.390020  1452.0
# 9   143645.796685   882.0
# 10  159606.203350   408.0
# 11  175566.610015   216.0
# 12  191527.016680   206.0
# 13  207487.423345   167.0
# 14  223447.830010   129.0
# 15  239408.236675   111.0
# 16  255368.643340    66.0
# 17  271329.050005    48.0
# 18  287289.456670    10.0
# 19  303249.863335    11.0

# %%
columns_bins_counts=['Bin','Count']
dict_counts_bins_df = pd.DataFrame(dict_counts_bins)
print (dict_counts_bins_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 columns_bins_counts=['Bin','Count']
# ----> 2 dict_counts_bins_df = pd.DataFrame(dict_counts_bins)
#       3 print (dict_counts_bins_df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
,columns=columns_bins_counts
