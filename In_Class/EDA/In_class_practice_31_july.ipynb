# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import seaborn as sas

# %%
visa_df = pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df_unique_case_status = visa_df['case_status'].unique()
count = []
for i in case_status_unique:
    con = visa_df['case_status'] == i
    count.append (len (visa_df [con]))


cols = ['case_status','Number of applications']
case_status_df = pd.DataFrame(zip(visa_df_unique_case_status,count),columns=cols)
case_status_df.to_csv('case_status_df.csv',index=False)

# %%
case_status_df
# Out:
#   case_status  Number of applications
# 0      Denied                    8462
# 1   Certified                   17018

# %% [markdown]
# #### Bar plot
# - create the barplot for the above table

# %%
import matplotlib.pyplot as plt
plt.bar('case_status',
       'Number of applications',
       data=case_status_df)
plt.title('Bar Chart')
plt.xlabel('Case status')
plt.ylabel('Number of applications')
plt.savefig('Case_Status_vs_No_apps.jpg')
plt.show()

# %%
continent_df = pd.read_csv('Continents_df.csv')
continent_df
# Out:
#       Continents  Number of applications
# 0           Asia                   16861
# 1         Africa                     551
# 2  North America                    3292
# 3         Europe                    3732
# 4  South America                     852
# 5        Oceania                     192

# %%
plt.bar('Continents',
       'Number of applications',
       data=continent_df)
plt.title('Bar chart')
plt.xlabel('Continents')
plt.ylabel('Number of Applications')
plt.savefig('Continents_vs_No_Apps.jpg')
plt.show()
