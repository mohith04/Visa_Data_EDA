# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sas

# %%
visa_df = pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $isna$
# - isna and isnull both are same

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
# - first arguments: indices
# - indices will take some values in array: in a list
# - it tries to extract the data
# - that values we provided represent columns or rows
# - Axis = 0 represents rows, by default the value will be zero if we don't specify it
# - Axis = 1 represents columns

# %%
visa_df.take([10,23,48])
# this retrives 3 rows which we have given inside the list
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 10  EZYV11           Asia              Master's                  N
# 23  EZYV24  North America           High School                  N
# 48  EZYV49           Asia            Bachelor's                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 10                     N             2465         2004              Midwest
# 23                     N             1517         1884              Midwest
# 48                     N             2405         1933                South
#
#     prevailing_wage unit_of_wage full_time_position case_status
# 10         83588.56         Year                  Y   Certified
# 23         90108.38         Year                  N   Certified
# 48         86022.02         Year                  Y   Certified

# %%
visa_df.take([1,2,8,10],axis=1)
# we need to have the amount to columns that we are giving in the list but if we give more than the no of columns it will give error
# Out:
#       continent education_of_employee  prevailing_wage full_time_position
# 0          Asia           High School         592.2029                  Y
# 1          Asia              Master's       83425.6500                  Y
# 2          Asia            Bachelor's      122996.8600                  Y
# 3          Asia            Bachelor's       83434.0300                  Y
# 4        Africa              Master's      149907.3900                  Y
# ...         ...                   ...              ...                ...
# 25475      Asia            Bachelor's       77092.5700                  Y
# 25476      Asia           High School      279174.7900                  Y
# 25477      Asia              Master's      146298.8500                  N
# 25478      Asia              Master's       86154.7700                  Y
# 25479      Asia            Bachelor's       70876.9100                  Y
#
# [25480 rows x 4 columns]

# %% [markdown]
# $Case-3:$ Select 3 columns 2nd, 5th and 7th columns

# %%
visa_df.take([2,5,7],axis=1)
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take([2,5,7],axis=1).head().tail(2)
# Out:
#   education_of_employee  no_of_employees region_of_employment
# 3            Bachelor's               98                 West
# 4              Master's             1082                South

# %%
visa_df.take([2:5])
#Sliceing the will fail
# Out:
#   Cell In[13], line 1
#     visa_df.take([2:5])
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# - we want 100,200,300 rows from
# - 2,5 7 colums

# %%
visa_df.take ([100,200,300]).take([2,5,7],axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.take([2,5,7],axis=1).take([100,200,300])

# %% [markdown]
# $loc-iloc$
# - visa_df.iloc[rows,columns]
# - visa_df.iloc[start:stop,start:stop]
# - visa_df.iloc[start:stop:step,start:stop:step]
# - visa_df.iloc[[list of rows],[list of columns]]
#     - case-1: rows = [100,200,300] and columns = [2,5,7]
#     - case-2: rows = [100:105] and columns = [2,5,7]
#     - case-3: rows = [100:105] and columns = [2:7]
#     - case-4: rows = [100,200,300] and columns = [2:7]
#     - case-5: rows = [100,200,300] and columns = :
#     - case-6: rows = : and columns = [2,5,7]

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[100:105,[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:105,2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 101              334         2007
# 102              224         2008
# 103              367         1982
# 104              306         2003

# %%
visa_df.iloc[[100,200,300],2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 200             Doctorate                  Y                     N
# 300              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 200             3282         1979
# 300             3268         2012

# %%
visa_df.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:,[2,5,7]]
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.iloc[100:110:2,2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 104              Master's                  Y                     N
# 106            Bachelor's                  N                     N
# 108            Bachelor's                  N                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 102              224         2008
# 104              306         2003
# 106              890         1981
# 108             2903         1943

# %%
visa_df.iloc[100:201:2,2:13:2]
# Out:
#     education_of_employee requires_job_training  yr_of_estab  prevailing_wage  \
# 100              Master's                     N         2007       28243.7900
# 102            Bachelor's                     N         2008       80253.7800
# 104              Master's                     N         2003       95200.8600
# 106            Bachelor's                     N         1981       64137.4100
# 108            Bachelor's                     N         1943       97520.0200
# 110           High School                     N         1956       73957.1700
# 112            Bachelor's                     N         1974       87336.5300
# 114             Doctorate                     N         1985       83503.6000
# 116            Bachelor's                     N         1997       32400.2000
# 118            Bachelor's                     N         1984       32161.6000
# 120              Master's                     N         1971      160676.3900
# ...

# %%
visa_df.iloc[:,2]
# this is a s series and if enclose 2 in square bracket then it will become a data frame
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[2]]
# this is a data frame
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.loc[:,['case_id','prevailing_wage','case_status']]
# Out:
#          case_id  prevailing_wage case_status
# 0         EZYV01         592.2029      Denied
# 1         EZYV02       83425.6500   Certified
# 2         EZYV03      122996.8600      Denied
# 3         EZYV04       83434.0300      Denied
# 4         EZYV05      149907.3900   Certified
# ...          ...              ...         ...
# 25475  EZYV25476       77092.5700   Certified
# 25476  EZYV25477      279174.7900   Certified
# 25477  EZYV25478      146298.8500   Certified
# 25478  EZYV25479       86154.7700   Certified
# 25479  EZYV25480       70876.9100   Certified
#
# [25480 rows x 3 columns]

# %%
visa_df.take([10,1,2],axis=1)
# Out:
#       full_time_position continent education_of_employee
# 0                      Y      Asia           High School
# 1                      Y      Asia              Master's
# 2                      Y      Asia            Bachelor's
# 3                      Y      Asia            Bachelor's
# 4                      Y    Africa              Master's
# ...                  ...       ...                   ...
# 25475                  Y      Asia            Bachelor's
# 25476                  Y      Asia           High School
# 25477                  N      Asia              Master's
# 25478                  Y      Asia              Master's
# 25479                  Y      Asia            Bachelor's
#
# [25480 rows x 3 columns]
