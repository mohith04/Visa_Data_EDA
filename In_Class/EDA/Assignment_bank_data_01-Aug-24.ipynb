# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
bank_df = pd.read_csv('bank.csv',sep = ";")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.to_csv('Bank_data_sep.csv',index=False)

# %%
bank_df.head(16)
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# ...

# %%
bank_df.tail(6)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4515   32       services   single  secondary      no      473     yes   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# ...

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.size
# Out:
# 76857

# %%
bank_df.shape
# Out:
# (4521, 17)

# %%
bank_df.shape[0]*bank_df.shape[1]
# Out:
# 76857

# %%
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bank_df_dtypes = dict(bank_df.dtypes)
bank_df_dtypes
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
catego_bank = [i for i, j in bank_df_dtypes.items () if j == 'object']
numer_bank = [i for i, j in bank_df_dtypes.items() if j!='object']
print (catego_bank,'\n',numer_bank)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']
#  ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
bank_df_for_keys = [keys for keys,values in bank_df_dtypes.items ()]
bank_df_for_values = [values for keys,values in bank_df_dtypes.items ()]

# %%
bank_df_keys = bank_df.select_dtypes(include='object').columns
bank_df_values = bank_df.select_dtypes(exclude='object').columns

# %%
bank_df_dtypes_table = pd.DataFrame(zip(bank_df_for_keys,bank_df_for_values),
                                    columns=['Bank data names','Bank data dtypes'])
bank_df_dtypes_table.to_csv("bank_dtypes_table.csv",index=False)
bank_df_dtypes_table
# Out:
#    Bank data names Bank data dtypes
# 0              age            int64
# 1              job           object
# 2          marital           object
# 3        education           object
# 4          default           object
# 5          balance            int64
# 6          housing           object
# 7             loan           object
# 8          contact           object
# 9              day            int64
# 10           month           object
# 11        duration            int64
# 12        campaign            int64
# 13           pdays            int64
# 14        previous            int64
# 15        poutcome           object
# 16               y           object

# %%
bank_df_new = pd.read_csv('Bank_data_sep.csv')
bank_df_new
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df_job = bank_df_new['job'].value_counts()
bank_df_job_dict = dict(bank_df_job)
bank_df_job
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64

# %%
bank_df_job_dict
# Out:
# {'management': 969,
#  'blue-collar': 946,
#  'technician': 768,
#  'admin.': 478,
#  'services': 417,
#  'retired': 230,
#  'self-employed': 183,
#  'entrepreneur': 168,
#  'unemployed': 128,
#  'housemaid': 112,
#  'student': 84,
#  'unknown': 38}

# %%
bank_df_new['job'].value_counts().values
# Out:
# array([969, 946, 768, 478, 417, 230, 183, 168, 128, 112,  84,  38],
#       dtype=int64)

# %%
bank_df_new.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
root_directory = os.getcwd()
new_folder = 'Bank_graph'
new_dir = os.path.join(root_directory, new_folder)
if not os.path.exists(new_dir):
 os.makedirs(new_dir)
 print(f"Directory '{new_dir}' created successfully.")
else:
 print(f"Directory '{new_dir}' already exists.")
# Out:
# Directory 'C:\Users\mohit\Data_Science\In_Class\EDA\Bank_graph' already exists.

# %%
for i in bank_df_keys[1:]:
    plt.figure(figsize=(8,5))
    order_bank = bank_df_new[i].value_counts().keys()
    sns.countplot(data = bank_df_new,
                 x = i,
                 order = order_bank)
    plt.title('Bar chart')
    plt.savefig(f'{new_dir}\\{i}_seaborn.jpg')
    plt.show()

# %%
root_directory = os.getcwd()
new_folder_bar = 'graphs_matplotlib'
new_dir_bar = os.path.join(root_directory, new_folder_bar)
if not os.path.exists(new_dir_bar):
 os.makedirs(new_dir_bar)
 print(f"Directory '{new_dir_bar}' created successfully.")
else:
 print(f"Directory '{new_dir_bar}' already exists.")
# Out:
# Directory 'C:\Users\mohit\Data_Science\In_Class\EDA\graphs_matplotlib' already exists.

# %%
for i in catego_bank[1:]:
    plt.figure(figsize=(8, 5))
    value_counts = bank_df[i].value_counts()
    categories = value_counts.index
    counts = value_counts.values
    plt.bar(categories, counts)
    plt.title('Bar chart')
    plt.xlabel(i)
    plt.ylabel('Count')
    plt.savefig(f'{new_dir}/{i}_matplotlib.jpg')
    plt.show()

# %%
numer_bank_df = pd.DataFrame(numer_bank)

# %%
count,bins,x = plt.hist(numer_bank_df,10)
print(len(count))
print (len(bins))
print (x)
# Out:
# 10
# 11
# <BarContainer object of 10 artists>
